# %% [markdown]
# # WEB SCRAPING USING BEAUTIFULSOUP

# %%
import requests
from bs4 import BeautifulSoup   # bs4 --used to call beautifulsoup.

# %%
web = requests.get("https://www.rbmi.in/") # response 200 means i can read and work on this websites
print(web)
# Out:
# <Response [200]>

# %%
web.content
# Out:
# b'<!DOCTYPE html><!-- Last Published: Tue Jan 07 2025 06:47:31 GMT+0000 (Coordinated Universal Time) -->\n<html data-wf-domain="www.rbmi.in" data-wf-page="66aca13f24279ac628932e6f" data-wf-site="66aca13f24279ac628932e6e" lang="en" data-wf-locale="en">\n   <head>\n      <meta charset="utf-8"/>\n      <title>RBMI - Best Engineering, Management, Nursing, MCA College in Bareilly</title>\n      <meta content="best colleges in bareilly,colleges in bareilly,private colleges in bareilly,best colleges in up,mba colleges in up,mba colleges in bareilly,best mba colleges in bareilly,best bba colleges in uttar pradesh,bba colleges in bareilly,mca colleges in bareilly,best mca colleges in uttar pradesh,bca colleges in up,bca colleges in bareilly,btech colleges in uttar pradesh,best btech colleges in up,btech colleges in up,btech colleges in bareilly,b tech mechanical engineering colleges,best colleges in up for btech computer science,best colleges in UP for Btech AI,best polytechnic colleges in up
# ...

# %%
web.url
# Out:
# 'https://www.rbmi.in/'

# %%
web.status_code  # to see website response
# Out:
# 200

# %%
soup = BeautifulSoup(web.content,"html.parser")             # soup object call the class of beautifulsoup

# %%
print(soup.prettify())    # soup.prettify used to convert html code into right formation.
# Out:
# <!DOCTYPE html>
# <!-- Last Published: Tue Jan 07 2025 06:47:31 GMT+0000 (Coordinated Universal Time) -->
# <html data-wf-domain="www.rbmi.in" data-wf-locale="en" data-wf-page="66aca13f24279ac628932e6f" data-wf-site="66aca13f24279ac628932e6e" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    RBMI - Best Engineering, Management, Nursing, MCA College in Bareilly
#   </title>
# ...

# %%
print(soup.body.prettify())
# Out:
# <body class="body">
#  <div class="w-embed w-iframe">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NL7RLLWF" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#  </div>
#  <div class="navbar w-nav" data-animation="default" data-collapse="medium" data-duration="400" data-easing="ease" data-easing2="ease" role="banner">
#   <div class="container-navigation">
#    <div class="navigation-left">
#     <nav class="nav-menu w-nav-menu" role="navigation">
#      <a class="nav-link w-nav-link" href="#About">
#       Home
#      </a>
#      <a class="nav-link w-nav-link" href="#Work">
#       About us
#      </a>
#      <a class="nav-link w-nav-link" href="/courses.html">
#       Courses
#      </a>
#      <a class="nav-link w-nav-link" href="#Services">
#       Campuses
#      </a>
# ...

# %%
soup.title
# Out:
# <title>RBMI - Best Engineering, Management, Nursing, MCA College in Bareilly</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.p  # used to see 1st paragraph tag.
# Out:
# <p class="text-black-6">RBMI embodies the principle of learning by doing, fostering hands-on experiences and practical skill development. </p>

# %%
soup.a    # used to see 1st anker tag
# Out:
# <a class="nav-link w-nav-link" href="#About">Home</a>

# %%
soup.h1 # used to see 1st header tag
# Out:
# <h1 class="heading-56">Bareilly Campus</h1>

# %% [markdown]
# # kinda of objects in beautifulsoup

# %% [markdown]
# # Tag

# %%
tag = soup.html  # with the help of this tag we get things like paragraph tag, anker tag, image tag

# %%
type (tag)
# Out:
# bs4.element.Tag

# %%
tag = soup.p   # used to see paragraph tag
tag
# Out:
# <p class="text-black-6">RBMI embodies the principle of learning by doing, fostering hands-on experiences and practical skill development. </p>

# %%
tag = soup.a # used to see anker tag
tag
# Out:
# <a class="nav-link w-nav-link" href="#About">Home</a>

# %%
tag = soup.h1
tag
# Out:
# <h1 class="heading-56">Bareilly Campus</h1>

# %%
tag = soup.h1
tag
# Out:
# <h1 class="heading-56">Bareilly Campus</h1>

# %%
taf = soup.h2
tag
# Out:
# <h1 class="heading-56">Bareilly Campus</h1>

# %% [markdown]
# # Navigablestring

# %%
# Navigablestring  ---it is used to get string
tag = soup.p.string
tag
# Out:
# 'RBMI embodies the principle of learning by doing, fostering hands-on experiences and practical skill development. '

# %%
tag = soup.a.string
tag
# Out:
# 'Home'

# %%
tag = soup.h1.string
tag
# Out:
# 'Bareilly Campus'

# %% [markdown]
# # Beautifulsoup

# %%
# it is used to create soup(object)
#soup.name
#soup.title
#soup.head
soup.body
# Out:
# <body class="body">
# <div class="w-embed w-iframe">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NL7RLLWF" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# </div>
# <div class="navbar w-nav" data-animation="default" data-collapse="medium" data-duration="400" data-easing="ease" data-easing2="ease" role="banner">
# <div class="container-navigation">
# <div class="navigation-left">
# <nav class="nav-menu w-nav-menu" role="navigation">
# <a class="nav-link w-nav-link" href="#About">Home</a><a class="nav-link w-nav-link" href="#Work">About us</a><a class="nav-link w-nav-link" href="/courses.html">Courses</a><a class="nav-link w-nav-link" href="#Services">Campuses</a><a class="nav-link w-nav-link" href="/alumni.html">Alumni</a>
# <div class="navbar-mobile-button-wrapper"><a class="button-primary w-button" href="#">Login</a></div>
# </nav>
# ...

# %%
soup.name
# Out:
# '[document]'

# %%
soup.title
# Out:
# <title>RBMI - Best Engineering, Management, Nursing, MCA College in Bareilly</title>

# %%
soup.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>RBMI - Best Engineering, Management, Nursing, MCA College in Bareilly</title>
# ...

# %% [markdown]
# # soup function

# %%
# soup function --contain function
# soup.find()   #   it give information of only first h1 tag.
# soup.find_all()  # it give information of all h1 tag.

# %%
 soup.find()
# Out:
# <html data-wf-domain="www.rbmi.in" data-wf-locale="en" data-wf-page="66aca13f24279ac628932e6f" data-wf-site="66aca13f24279ac628932e6e" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>RBMI - Best Engineering, Management, Nursing, MCA College in Bareilly</title>
# ...

# %%
soup.find_all()
# Out:
# [<html data-wf-domain="www.rbmi.in" data-wf-locale="en" data-wf-page="66aca13f24279ac628932e6f" data-wf-site="66aca13f24279ac628932e6e" lang="en">
#  <head>
#  <meta charset="utf-8"/>
#  <title>RBMI - Best Engineering, Management, Nursing, MCA College in Bareilly</title>
# ...

# %% [markdown]
# # comments

# %%
# it is used to find commented  data

# %%
com = soup.p.string
com
# Out:
# 'RBMI embodies the principle of learning by doing, fostering hands-on experiences and practical skill development. '

# %%
soup.p.prettify ()
# Out:
# '<p class="text-black-6">\n RBMI embodies the principle of learning by doing, fostering hands-on experiences and practical skill development.\n</p>\n'

# %% [markdown]
# # Finding elements in web page using python
# # finding elements
# # 1] finding elements by class
# # 2] finding elements by id

# %%
soup.find_all('p')
# soup.find_all('a')   # to find tag  -----like paragraph tag
# soup.find_all('h1')
# soup.find_all('h2')
# Out:
# [<p class="text-black-6">RBMI embodies the principle of learning by doing, fostering hands-on experiences and practical skill development. </p>,
#  <p class="text-black-6">The training approach at RBMI underscores hands-on experiences to prepare students for real-world challenges.</p>,
#  <p class="text-black-6">RBMI is committed to facilitating successful career placements for its students in premier companies and top-tier organisations.</p>,
#  <p class="paragraph-49">Nov</p>,
#  <p class="paragraph-48">Enrolment form for Diploma All</p>,
#  <p class="paragraph-49">Dec</p>,
#  <p class="paragraph-48">Counselling of BPharm and DPharm</p>,
#  <p class="paragraph-49">20-29 Nov</p>,
#  <p class="paragraph-48">Examination form BCA Last date</p>,
#  <p class="paragraph-49">January 31, 2025</p>,
#  <p class="paragraph-48">National Online Scholarship Test</p>,
#  <p class="paragraph-49">December 22, 2024</p>,
#  <p class="paragraph-48">Reconnect and Inspire with Akhlesh Mathur</p>,
# ...

# %%
soup.find_all('a')
# Out:
# [<a class="nav-link w-nav-link" href="#About">Home</a>,
#  <a class="nav-link w-nav-link" href="#Work">About us</a>,
#  <a class="nav-link w-nav-link" href="/courses.html">Courses</a>,
#  <a class="nav-link w-nav-link" href="#Services">Campuses</a>,
#  <a class="nav-link w-nav-link" href="/alumni.html">Alumni</a>,
#  <a class="button-primary w-button" href="#">Login</a>,
#  <a aria-current="page" class="brand w-nav-brand w--current" href="/"><img alt="" class="logo" loading="lazy" src="image/66aca13f24279ac628933687_RBMI%20LOGO.svg"/></a>,
#  <a class="search-btn w-inline-block" data-w-id="f368324e-993f-b3d7-3713-5b791e088ba4" href="#"><img alt="" class="image-39" loading="lazy" src="image/66aca13f24279ac628932f34_Vector.svg"/></a>,
#  <a class="hamburger-top w-button" data-w-id="f368324e-993f-b3d7-3713-5b791e088ba9" href="#"></a>,
# ...

# %%
soup.find_all('h1')
# Out:
# [<h1 class="heading-56">Bareilly Campus</h1>,
#  <h1 class="heading-56">Gr. Noida Campus</h1>,
#  <h1 class="heading-55">Bareilly Location</h1>,
#  <h1 class="heading-55">Greater Noida Location</h1>,
#  <h1 class="heading-55">Connect</h1>,
#  <h1 class="heading-61"><strong class="h-l-44 dark-blue regular-font">Empowering Minds, Shaping Leaders.</strong></h1>,
#  <h1 class="heading-60 is-size"><span class="counter">28</span>+</h1>,
#  <h1 class="heading-60 is-size"><span class="counter">7</span></h1>,
#  <h1 class="heading-60 is-size"><span class="counter">25000</span>+</h1>,
#  <h1 class="heading-60"><span class="counter">7</span></h1>,
#  <h1 class="heading-60"><span class="counter">28</span>+</h1>,
#  <h1 class="heading-60"><span class="counter">25000</span>+</h1>,
#  <h1 class="heading-58 hide-in-mb" data-w-id="58d879c0-bfe1-f7fb-87a1-66731e131ad3" style="opacity:0">Welcome to<strong class="bold-heading"><br/>Bareilly Campus</strong></h1>,
# ...

# %%
soup.find_all('h2')
# Out:
# [<h2 class="heading-69">Which Campus are<br/> you interested in?</h2>]

# %%
# finding elements by class
class_data = soup.find("div", class_="div-block-16")

class_data
# Out:
# <div class="div-block-16">
# <div class="div-block-208">
# <a class="button-15 w-button" data-w-id="c497fcfb-478f-6c45-0ab2-523262406362" href="#"></a>
# <div class="div-block-18">
# <div class="w-layout-grid grid-6">
# <a class="div-block-19 w-inline-block" data-w-id="54ebf7cc-9e3b-3d46-b6ff-e066fd57d491" href="/book-a-counselling-session.html">
# <img alt="" class="image-1" loading="lazy" src="image/66aca13f24279ac628932ec6_Layer_1.svg"/><img alt="" class="image-92" loading="lazy" src="image/66aca13f24279ac62893373d_Layer_1.svg"/>
# <div class="text-block-12">Book an<br/>Appointment</div>
# </a>
# <a class="div-block-19 w-inline-block" data-w-id="544582c3-c160-fe5f-86d5-3b53d45a5342" href="/book-a-campus-visit.html">
# <img alt="" class="image-1" loading="lazy" src="image/66aca13f24279ac628932ec4_Vector.svg"/><img alt="" class="image-92" loading="lazy" src="image/66aca13f24279ac62893373c_Vector%20(9).svg"/>
# <div class="text-block-12">Book Campus Visit</div>
# </a>
# ...

# %%
class_data.find_all("a")  # it give anker tag
# Out:
# [<a class="button-15 w-button" data-w-id="c497fcfb-478f-6c45-0ab2-523262406362" href="#"></a>,
#  <a class="div-block-19 w-inline-block" data-w-id="54ebf7cc-9e3b-3d46-b6ff-e066fd57d491" href="/book-a-counselling-session.html">
#  <img alt="" class="image-1" loading="lazy" src="image/66aca13f24279ac628932ec6_Layer_1.svg"/><img alt="" class="image-92" loading="lazy" src="image/66aca13f24279ac62893373d_Layer_1.svg"/>
#  <div class="text-block-12">Book an<br/>Appointment</div>
#  </a>,
#  <a class="div-block-19 w-inline-block" data-w-id="544582c3-c160-fe5f-86d5-3b53d45a5342" href="/book-a-campus-visit.html">
#  <img alt="" class="image-1" loading="lazy" src="image/66aca13f24279ac628932ec4_Vector.svg"/><img alt="" class="image-92" loading="lazy" src="image/66aca13f24279ac62893373c_Vector%20(9).svg"/>
#  <div class="text-block-12">Book Campus Visit</div>
#  </a>,
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Acer Aspire 3\anaconda3\python.exe

# %%
id_data = soup.find("div", id ="820a8266-1a1c-b1de-54e8-96e9332167a4")

# %%
id_data.find_all("p")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 id_data.find_all("p")
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
# !{sys.executable} -m pip install requests-html --pre
# Out:
# 'C:\Users\Acer' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from requests_html import HTMLSession
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 from requests_html import HTMLSession
#
# ModuleNotFoundError: No module named 'requests_html'

# %%
# !{sys.executable} -m pip install requests-html --pre
# Out:
# 'C:\Users\Acer' is not recognized as an internal or external command,
# operable program or batch file.
